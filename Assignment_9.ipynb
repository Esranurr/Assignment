# %%
name = "Joseph"
password = "W@12"


giris = input("Enter a name, please : ").title().strip()

if name == giris :
  print("Hello, {} ! The password is : {} ".format(name, password))
else :
  print("Hello, {} ! See you later.".format(giris))
# Out:
# Enter a name please : joseph
# Hello, Joseph ! The password is : W@12
